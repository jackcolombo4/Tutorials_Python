# %% [markdown]
# <div style="line-height:0.5">
# <h1 style="color:lightcoral"> Pandas basics 4 </h1>
# </div>
# <div style="line-height:1.5">
# <div style="margin-top: -14px;">
# <span style="display: inline-block;">
#     <h3 style="color: lightblue; display: inline;">Keywords:</h3> pprint + pivot_table + cmap
# </span>
# </div>
# </div>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pprint import pprint 
import matplotlib.cm as cm

# %%
ava = sns.get_dataset_names()
ava
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
base_url = 'https://people.sc.fsu.edu/~jburkardt/data/'
url1 = 'https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv'
url2 = 'https://people.sc.fsu.edu/~jburkardt/data/csv/cities.csv'

excel_file_name = 'cities.xlsx'
json_file_name = 'cities.json'
excel_file_url = base_url + excel_file_name
json_file_url = base_url + json_file_name

dataframeurl = pd.read_csv(url1)
dataframeurl2 = pd.read_csv(url2)

# dataframeurl.head(22)
# dataframeurl2.head(22)

# %%
df = sns.load_dataset('planets')
df.head(10)
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009
# 5  Radial Velocity       1         185.840   4.80     76.39  2008
# 6  Radial Velocity       1        1773.400   4.64     18.15  2002
# 7  Radial Velocity       1         798.500    NaN     21.41  1996
# 8  Radial Velocity       1         993.300  10.30     73.10  2008
# 9  Radial Velocity       2         452.800   1.99     74.79  2010

# %%
df = pd.read_excel('https://github.com/datagy/mediumdata/raw/master/sample_pivot.xlsx', parse_dates=['Date'])

print(df.head())
# Out:
#         Date Region                 Type  Units  Sales
# 0 2020-07-11   East  Children's Clothing   18.0    306
# 1 2020-09-23  North  Children's Clothing   14.0    448
# 2 2020-04-02  South     Women's Clothing   17.0    425
# 3 2020-02-28   East  Children's Clothing   26.0    832
# 4 2020-03-19   West     Women's Clothing    3.0     33

# %%
pivot = pd.pivot_table(df, index = ['Region', 'Type'], values = 'Sales', aggfunc = 'sum')
pivot.head()
# Out:
#                             Sales
# Region Type
# East   Children's Clothing  45849
#        Men's Clothing       51685
#        Women's Clothing     70229
# North  Children's Clothing  37306
#        Men's Clothing       39975

# %%
pivot.style.format({'Sales':'${0:,.0f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_39e80">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39e80_level0_col0" class="col_heading level0 col0" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="index_name level1" >Type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39e80_level0_row0" class="row_heading level0 row0" rowspan="3">East</th>
#       <th id="T_39e80_level1_row0" class="row_heading level1 row0" >Children's Clothing</th>
#       <td id="T_39e80_row0_col0" class="data row0 col0" >$45,849</td>
#     </tr>
#     <tr>
#       <th id="T_39e80_level1_row1" class="row_heading level1 row1" >Men's Clothing</th>
#       <td id="T_39e80_row1_col0" class="data row1 col0" >$51,685</td>
#     </tr>
#     <tr>
# ...

# %%
format_dictionary = {
   'column1':'format1', 
   'column2':'format2'
   }
pivot.style.format(format_dictionary)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6759c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6759c_level0_col0" class="col_heading level0 col0" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="index_name level1" >Type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6759c_level0_row0" class="row_heading level0 row0" rowspan="3">East</th>
#       <th id="T_6759c_level1_row0" class="row_heading level1 row0" >Children's Clothing</th>
#       <td id="T_6759c_row0_col0" class="data row0 col0" >45849</td>
#     </tr>
#     <tr>
#       <th id="T_6759c_level1_row1" class="row_heading level1 row1" >Men's Clothing</th>
#       <td id="T_6759c_row1_col0" class="data row1 col0" >51685</td>
#     </tr>
#     <tr>
# ...

# %%
def highlight_fifty(val):
    color = 'red' if val > 50000 else 'black'
    return 'color: %s' % color

pivot_highlight = pivot.style.applymap(highlight_fifty)
pivot_highlight
# Out:
# <style type="text/css">
# #T_98848_row0_col0, #T_98848_row3_col0, #T_98848_row4_col0, #T_98848_row6_col0, #T_98848_row7_col0, #T_98848_row8_col0, #T_98848_row9_col0, #T_98848_row10_col0, #T_98848_row11_col0 {
#   color: black;
# }
# #T_98848_row1_col0, #T_98848_row2_col0, #T_98848_row5_col0 {
#   color: red;
# }
# </style>
# <table id="T_98848">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98848_level0_col0" class="col_heading level0 col0" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="index_name level1" >Type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98848_level0_row0" class="row_heading level0 row0" rowspan="3">East</th>
#       <th id="T_98848_level1_row0" class="row_heading level1 row0" >Children's Clothing</th>
# ...

# %%
pivot_highlight = pivot.style.applymap(highlight_fifty).format({'Sales':'${0:,.0f}'})
pivot_highlight
# Out:
# <style type="text/css">
# #T_74255_row0_col0, #T_74255_row3_col0, #T_74255_row4_col0, #T_74255_row6_col0, #T_74255_row7_col0, #T_74255_row8_col0, #T_74255_row9_col0, #T_74255_row10_col0, #T_74255_row11_col0 {
#   color: black;
# }
# #T_74255_row1_col0, #T_74255_row2_col0, #T_74255_row5_col0 {
#   color: red;
# }
# </style>
# <table id="T_74255">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74255_level0_col0" class="col_heading level0 col0" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="index_name level1" >Type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74255_level0_row0" class="row_heading level0 row0" rowspan="3">East</th>
#       <th id="T_74255_level1_row0" class="row_heading level1 row0" >Children's Clothing</th>
# ...

# %%
pivot_highlight = pivot.style.format({'Sales':'${0:,.0f}'})\
   .highlight_max(color='green')\
   .highlight_min(color='red')
pivot_highlight
# Out:
# <style type="text/css">
# #T_34453_row2_col0 {
#   background-color: green;
# }
# #T_34453_row7_col0 {
#   background-color: red;
# }
# </style>
# <table id="T_34453">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34453_level0_col0" class="col_heading level0 col0" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="index_name level1" >Type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34453_level0_row0" class="row_heading level0 row0" rowspan="3">East</th>
#       <th id="T_34453_level1_row0" class="row_heading level1 row0" >Children's Clothing</th>
#       <td id="T_34453_row0_col0" class="data row0 col0" >$45,849</td>
#     </tr>
#     <tr>
#       <th id="T_34453_level1_row1" class="row_heading level1 row1" >Men's Clothing</th>
# ...

# %%
pivot.style.format({'Sales':'${0:,.0f}'}) \
   .highlight_max(color='green') \
   .highlight_min(color='red')
# Out:
# <style type="text/css">
# #T_d8d51_row2_col0 {
#   background-color: green;
# }
# #T_d8d51_row7_col0 {
#   background-color: red;
# }
# </style>
# <table id="T_d8d51">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8d51_level0_col0" class="col_heading level0 col0" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="index_name level1" >Type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8d51_level0_row0" class="row_heading level0 row0" rowspan="3">East</th>
#       <th id="T_d8d51_level1_row0" class="row_heading level1 row0" >Children's Clothing</th>
#       <td id="T_d8d51_row0_col0" class="data row0 col0" >$45,849</td>
#     </tr>
#     <tr>
#       <th id="T_d8d51_level1_row1" class="row_heading level1 row1" >Men's Clothing</th>
# ...

# %%
pivot.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_3bbc5_row0_col0 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_3bbc5_row1_col0 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_3bbc5_row2_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3bbc5_row3_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_3bbc5_row4_col0 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_3bbc5_row5_col0 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_3bbc5_row6_col0, #T_3bbc5_row7_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_3bbc5_row8_col0, #T_3bbc5_row11_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_3bbc5_row9_col0 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_3bbc5_row10_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# </style>
# <table id="T_3bbc5">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
pivot2 = pd.pivot_table(df, index = ['Region', 'Type'], values = 'Sales', aggfunc = ['sum','count'])
pivot2.head()
# Out:
#                               sum count
#                             Sales Sales
# Region Type
# East   Children's Clothing  45849   113
#        Men's Clothing       51685   122
#        Women's Clothing     70229   176
# North  Children's Clothing  37306    85
#        Men's Clothing       39975    89

# %%
pivot2.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_eda68_row0_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_eda68_row0_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_eda68_row1_col0 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_eda68_row1_col1 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_eda68_row2_col0, #T_eda68_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_eda68_row3_col0 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_eda68_row3_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_eda68_row4_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_eda68_row4_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_eda68_row5_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_eda68_row5_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_eda68_row6_col0, #T_eda68_row7_col0, #T_eda68_row7_col1 {
#   background-color: #f7fbff;
# ...

# %%
pivot2.style.background_gradient(subset=['sum'], cmap='BrBG')
# Out:
# <style type="text/css">
# #T_ae341_row0_col0 {
#   background-color: #e7f2f0;
#   color: #000000;
# }
# #T_ae341_row1_col0 {
#   background-color: #a8ddd5;
#   color: #000000;
# }
# #T_ae341_row2_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_ae341_row3_col0 {
#   background-color: #edd9a8;
#   color: #000000;
# }
# #T_ae341_row4_col0 {
#   background-color: #f6eacb;
#   color: #000000;
# }
# #T_ae341_row5_col0 {
#   background-color: #258880;
#   color: #f1f1f1;
# }
# #T_ae341_row6_col0, #T_ae341_row7_col0 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_ae341_row8_col0, #T_ae341_row11_col0 {
#   background-color: #7c4709;
#   color: #f1f1f1;
# }
# #T_ae341_row9_col0 {
#   background-color: #663a07;
#   color: #f1f1f1;
# }
# #T_ae341_row10_col0 {
#   background-color: #583305;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ae341">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
print(cm.datad.keys())
# Out:
# dict_keys(['Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c'])

# %%
pivot.style.format({'Sales':'${0:,.0f}'}).bar(color='Green') # no datad palettes but single color here
# Out:
# <style type="text/css">
# #T_1f37b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 65.3%, transparent 65.3%);
# }
# #T_1f37b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 73.6%, transparent 73.6%);
# }
# #T_1f37b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 100.0%, transparent 100.0%);
# }
# #T_1f37b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 53.1%, transparent 53.1%);
# }
# #T_1f37b_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 56.9%, transparent 56.9%);
# }
# #T_1f37b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 87.5%, transparent 87.5%);
# }
# #T_1f37b_row6_col0, #T_1f37b_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 26.4%, transparent 26.4%);
# }
# #T_1f37b_row8_col0, #T_1f37b_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 31.6%, transparent 31.6%);
# }
# ...

# %%
style1 = pivot.copy()
style1.style.format({'Sales':'${0:,.0f}'}).bar(color='Green')
# Out:
# <style type="text/css">
# #T_b071f_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 65.3%, transparent 65.3%);
# }
# #T_b071f_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 73.6%, transparent 73.6%);
# }
# #T_b071f_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 100.0%, transparent 100.0%);
# }
# #T_b071f_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 53.1%, transparent 53.1%);
# }
# #T_b071f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 56.9%, transparent 56.9%);
# }
# #T_b071f_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 87.5%, transparent 87.5%);
# }
# #T_b071f_row6_col0, #T_b071f_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 26.4%, transparent 26.4%);
# }
# #T_b071f_row8_col0, #T_b071f_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, Green 31.6%, transparent 31.6%);
# }
# ...
