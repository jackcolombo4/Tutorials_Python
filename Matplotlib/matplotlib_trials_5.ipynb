# %% [markdown]
# <div style="line-height:0.5">
# <h1 style="color:slateblue "> Matplotlib trials 5 </h1>
# </div>
# <div style="line-height:1.5">
# <div style="margin-top: -14px;">
# <span style="display: inline-block;">
#     <h3 style="color: lightblue; display: inline;">Keywords:</h3> savefig + matplotlib rcParams[] + matplotlib set_facecolor()
# </span>
# </div>
# </div>

# %%
# %config Completer.use_jedi = False
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# %config Completer.use_jedi = False
#
# Disabling Jedi (Jupyter notebooks completer) that sometimes is slow or not work as expected.
# This configuration is not necessary when using notebooks in VSCode, but it specific to the classic Jupyter notebook server interface running in a browser.

# %%
sample_quiet0 = [0.22, 0.21, 0.21, 0.22, 0.22, 0.22, 0.22, 0.22, 0.22, 0.22]
sample_quiet1 = [0.19, 0.19, 0.20, 0.19, 0.20, 0.19, 0.20, 0.20, 0.19, 0.20]
sample_quiet2 = [0.26, 0.27, 0.27, 0.26, 0.27, 0.27, 0.27, 0.27, 0.27, 0.26]
sample_quiet3 = [0.23, 0.23, 0.23, 0.23, 0.23, 0.23, 0.22, 0.23, 0.23, 0.23]
sample_quiet4 = [0.22, 0.23, 0.23, 0.22, 0.22, 0.23, 0.23, 0.23, 0.22, 0.23]

gyro_quiet_l = [52, 53, 47, 47, 51, 50, 48, 53, 49, 49]
gyro_quiet_r = [-152, -151, -152, -154, -151, -153, -153, -153, -150, -152]
##########################################################################################################################################
sample_caress0 = [0.22, 0.22, 0.21, 0.22, 0.21, 0.22, 0.22, 0.22, 0.21, 0.22]
sample_caress1 = [0.20, 0.20, 0.20, 0.21, 0.19, 0.20, 0.20, 0.20, 0.20, 0.20]
sample_caress2 = [0.28, 0.28, 0.29, 0.28, 0.28, 0.29, 0.28, 0.28, 0.28, 0.29]
sample_caress3 = [0.23, 0.23, 0.22, 0.23, 0.23, 0.23, 0.23, 0.23, 0.23, 0.23]
sample_caress4 = [0.22, 0.21, 0.22, 0.21, 0.21, 0.21, 0.22, 0.21, 0.22, 0.21]

gyro_caress_l = [37, 41, -5, 42, 52, 43, 70, 47, 42, 55]
gyro_caress_r = [-158, -150, -190, -154, -134, -152, -121, -147, -144, -132]
##########################################################################################################################################
sample_touch0 = [0.23, 0.24, 0.24, 0.23, 0.24, 0.23, 0.24, 0.24, 0.23, 0.24]
sample_touch1 = [0.20, 0.20, 0.20, 0.20, 0.21, 0.20, 0.20, 0.21, 0.21, 0.20]
sample_touch2 = [0.31, 0.31, 0.31, 0.30, 0.30, 0.31, 0.31, 0.31, 0.31, 0.31]
sample_touch3 = [0.22, 0.23, 0.23, 0.23, 0.23, 0.23, 0.23, 0.22, 0.23, 0.23]
sample_touch4 = [0.22, 0.22, 0.22, 0.22, 0.22, 0.22, 0.22, 0.23, 0.22, 0.22]

gyro_touch_l = [49, 49, 48, 49, 43, 48, 49, 48, 47, 49]
gyro_touch_r = [-151, -152, -146, -149, -155, -150, -150, -153, -149, -152]
##########################################################################################################################################
sample_hug0 = [0.38, 0.38, 0.38, 0.37, 0.38, 0.38, 0.38, 0.40, 0.39, 0.39]
sample_hug1 = [0.25, 0.25, 0.25, 0.26, 0.24, 0.25, 0.25, 0.25, 0.24, 0.25]
sample_hug2 = [0.38, 0.37, 0.38, 0.38, 0.37, 0.37, 0.38, 0.37, 0.37, 0.38]
sample_hug3 = [0.28, 0.28, 0.28, 0.27, 0.28, 0.27, 0.28, 0.27, 0.27, 0.27]
sample_hug4 = [0.30, 0.30, 0.29, 0.30, 0.29, 0.29, 0.30, 0.30, 0.31, 0.30]

gyro_hug_l = [43, 42, 40, 44, 45, 41, 40, 43, 38, 43]
gyro_hug_r = [-149, -152, -155, -151, -154, -154, -152, -150, -150, -154]
##########################################################################################################################################
sample_choke0 = [0.60, 0.59, 0.57, 0.57, 0.56, 0.55, 0.55, 0.54, 0.54, 0.52]
sample_choke1 = [0.31, 0.31, 0.30, 0.30, 0.30, 0.30, 0.30, 0.29, 0.29, 0.29]
sample_choke2 = [0.48, 0.48, 0.48, 0.47, 0.46, 0.46, 0.46, 0.46, 0.46, 0.45]
sample_choke3 = [0.53, 0.54, 0.52, 0.55, 0.53, 0.57, 0.61, 0.59, 0.51, 0.46]
sample_choke4 = [0.40, 0.39, 0.39, 0.39, 0.39, 0.39, 0.39, 0.38, 0.38, 0.37]

gyro_choke_l = [50, 49, 40, 47, 42, 43, 47, 44, 45, 44]
gyro_choke_r = [-153, -151, -154, -151, -154, -152, -152, -154, -152, -152]
##########################################################################################################################################
sample_squeeze0 = [0.29, 0.22, 0.22, 0.22, 0.23, 0.21, 0.22, 0.29, 0.23, 0.21]
sample_squeeze1 = [0.30, 0.22, 0.22, 0.27, 0.23, 0.21, 0.21, 0.27, 0.22, 0.21] 
sample_squeeze2 = [0.27, 0.27, 0.26, 0.28, 0.26, 0.27, 0.26, 0.28, 0.26, 0.26] 
sample_squeeze3 = [0.27, 0.23, 0.23, 0.27, 0.24, 0.23, 0.23, 0.28, 0.25, 0.23] 
sample_squeeze4 = [0.23, 0.22, 0.21, 0.22, 0.22, 0.22, 0.21, 0.23, 0.22, 0.22] 


gyro_squeeze_l = [23, 39, 67, 87, -22, -136, 100, 83, 56, -70]
gyro_squeeze_r = [-197, -174, -77, -155, -239, -440, -109, -351, -133, -175]
##########################################################################################################################################
sample_shove0 = [0.22, 0.22, 0.22, 0.22, 0.22, 0.22, 0.22, 0.22, 0.21, 0.22]
sample_shove1 = [0.20, 0.20, 0.20, 0.20, 0.20, 0.20, 0.20, 0.21, 0.20, 0.21]
sample_shove2 = [0.28, 0.28, 0.27, 0.28, 0.28, 0.27, 0.28, 0.28, 0.28, 0.28]
sample_shove3 = [0.23, 0.23, 0.23, 0.23, 0.23, 0.22, 0.23, 0.23, 0.23, 0.23]
sample_shove4 = [0.23, 0.24, 0.24, 0.24, 0.24, 0.24, 0.24, 0.24, 0.23, 0.24]

gyro_shove_l = [65, -120, 94, 48, 51, 54, 54, 51, 48, 47]
gyro_shove_r = [-128, -454, -100, -157, -150, -150, -152, -152, -151, -152]
##########################################################################################################################################
sample_hit0 = [0.22, 0.34, 0.34, 0.22, 0.22, 0.22, 0.22, 0.22, 0.22, 0.22]
sample_hit1 = [0.21, 0.25, 0.24, 0.21, 0.21, 0.21, 0.21, 0.21, 0.21, 0.21]
sample_hit2 = [0.28, 0.43, 0.44, 0.26, 0.27, 0.28, 0.27, 0.27, 0.27, 0.27]
sample_hit3 = [0.24, 0.28, 0.29, 0.24, 0.23, 0.24, 0.23, 0.23, 0.23, 0.24]
sample_hit4 = [0.22, 0.27, 0.26, 0.22, 0.22, 0.22, 0.22, 0.22, 0.22, 0.22]

gyro_hit_l = [15, 59, -48, 55, 59, 56, 55, 52, 50, 55]
gyro_hit_r = [-188, -167, -234, -154, -155, -151, -152, -151, -151, -151]

# %%
fig1 = plt.figure(1)
plt.plot(sample_quiet0, label="Other Test",  color='r')
plt.plot(sample_quiet1, label="Other Test",  color='b')
plt.plot(sample_quiet2, label="Other Test",  color='g')
plt.plot(sample_quiet3, label="Other Test",  color='c')
plt.plot(sample_quiet4, label="Other Test",  color='m')
plt.grid(True)
#plt.plot()
plt.tight_layout()

plt.savefig('./images_matplotlib/save_figure1.png')
#plt.show()

# %%
fig2 = plt.figure(1)
plt.plot(sample_hug0, label="Test", color='r')
plt.plot(sample_hug1, label="Other Test",  color='b')
plt.plot(sample_hug2, label="Other Test",  color='g')
plt.plot(sample_hug3, label="Other Test",  color='c')
plt.plot(sample_hug4, label="Other Test",  color='m')
plt.grid(True)
plt.show()

# %%
fig3 = plt.figure(1)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
ax = plt.axes()
ax.set_facecolor("whitesmoke")
fig3.suptitle('10 samples of touches MPX sensor 0', fontsize=16)
plt.plot(sample_quiet0, label="Quiet ", color='k', linewidth=2.5)
plt.plot(sample_caress0, label="Caress", color='b', linewidth=2.5)
plt.plot(sample_touch0, label="Touch", color='lime', linewidth=2.5)
plt.plot(sample_hug0, label="Hug",  color='c', linewidth=2.5)
plt.plot(sample_choke0, label="Choke",  color='purple', linewidth=2.5)
plt.plot(sample_squeeze0, label="Squeeze",  color='violet', linewidth=2.5)
plt.plot(sample_shove0, label='Shove', color='orange', linewidth=2.5)
plt.plot(sample_hit0, label="Hit",  color='r', linewidth=2.5)
plt.grid(True)
plt.xlabel("readings",fontweight='bold',fontsize=16)
plt.ylabel("pressure (psi)",fontweight='bold',fontsize=16)
l1 = plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0, fontsize=16)
plt.tight_layout()

plt.savefig('./images_matplotlib/sensor_0_pressure.png')
plt.show()

# %%
fig4 = plt.figure(1)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
ax = plt.axes()
ax.set_facecolor("whitesmoke")
fig4.suptitle('10 samples of touches MPX sensor 1', fontsize=16)
plt.plot(sample_quiet1, label="Quiet ", color='k', linewidth=2.5)
plt.plot(sample_caress1, label="Caress", color='b', linewidth=2.5)
plt.plot(sample_touch1, label="Touch", color='lime', linewidth=2.5)
plt.plot(sample_hug1, label="Hug",  color='c', linewidth=2.5)
plt.plot(sample_choke1, label="Choke",  color='purple', linewidth=2.5)
plt.plot(sample_squeeze1, label="Squeeze",  color='violet', linewidth=2.5)
plt.plot(sample_shove1, label='Shove', color='orange', linewidth=2.5)
plt.plot(sample_hit1, label="Hit",  color='r', linewidth=2.5)
plt.grid(True)
plt.xlabel("readings",fontweight='bold',fontsize=16)
plt.ylabel("pressure (psi)",fontweight='bold',fontsize=16)
l1 = plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0, fontsize=16);

# %%
fig5 = plt.figure(1)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
ax = plt.axes()
ax.set_facecolor("whitesmoke")
fig5.suptitle('Left gyroscope values for 10 samples', fontsize=16)
plt.plot(gyro_quiet_l, label="Quiet ", color='k', linewidth=2.5)
plt.plot(gyro_caress_l, label="Caress", color='b', linewidth=2.5)
plt.plot(gyro_touch_l, label="Touch", color='lime', linewidth=2.5)
plt.plot(gyro_hug_l, label="Hug",  color='c', linewidth=2.5)
plt.plot(gyro_choke_l, label="Choke",  color='purple', linewidth=2.5)
plt.plot(gyro_squeeze_l, label="Squeeze",  color='violet', linewidth=2.5)
plt.plot(gyro_shove_l, label='Shove', color='orange', linewidth=2.5)
plt.plot(gyro_hit_l, label="Hit",  color='r', linewidth=2.5)
plt.grid(True)
plt.xlabel("readings",fontweight='bold',fontsize=16)
plt.ylabel("gyroscope raw",fontweight='bold',fontsize=16)
l1 = plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0, fontsize=16)
plt.tight_layout()
plt.show()

# %%
fig6 = plt.figure(1)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
ax = plt.axes()
ax.set_facecolor("whitesmoke")
fig6.suptitle('Right gyroscope values for 10 samples', fontsize=16)
plt.plot(gyro_quiet_r, label="Quiet ", color='k', linewidth=2.5)
plt.plot(gyro_caress_r, label="Caress", color='b', linewidth=2.5)
plt.plot(gyro_touch_r, label="Touch", color='lime', linewidth=2.5)
plt.plot(gyro_hug_r, label="Hug",  color='c', linewidth=2.5)
plt.plot(gyro_choke_r, label="Choke",  color='purple', linewidth=2.5)
plt.plot(gyro_squeeze_r, label="Squeeze",  color='violet', linewidth=2.5)
plt.plot(gyro_shove_r, label='Shove', color='orange', linewidth=2.5)
plt.plot(gyro_hit_r, label="Hit",  color='r', linewidth=2.5)
plt.grid(True)
plt.xlabel("readings",fontweight='bold',fontsize=16)
plt.ylabel("gyroscope raw",fontweight='bold',fontsize=16)
l1 = plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0, fontsize=16)
#plt.tight_layout()
plt.show()

# %%
fig7 = plt.figure(1)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
ax = plt.axes()
ax.set_facecolor("whitesmoke")
fig7.suptitle('10 samples of touches MPX sensor 3', fontsize=16)
plt.plot(sample_quiet3, label="Quiet ", color='k', linewidth=2.5)
plt.plot(sample_caress3, label="Caress", color='b', linewidth=2.5)
plt.plot(sample_touch3, label="Touch", color='lime', linewidth=2.5)
plt.plot(sample_hug3, label="Hug",  color='c', linewidth=2.5)
plt.plot(sample_choke3, label="Choke",  color='purple', linewidth=2.5)
plt.plot(sample_squeeze3, label="Squeeze",  color='m', linewidth=2.5)
plt.plot(sample_shove3, label='Shove', color='orange', linewidth=2.5)
plt.plot(sample_hit3, label="Hit",  color='r', linewidth=2.5)
plt.grid(True)
plt.xlabel("readings",fontweight='bold',fontsize=16)
plt.ylabel("pressure (psi)",fontweight='bold',fontsize=16)
l1 = plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0, fontsize=16)
#plt.show()

# %%
fig8 = plt.figure(1)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
ax = plt.axes()
ax.set_facecolor("whitesmoke")

fig8.suptitle('10 samples of touches MPX sensor 2', fontsize=16)
plt.plot(sample_quiet2, label="Quiet ", color='k', linewidth=2.5)
plt.plot(sample_caress2, label="Caress", color='b', linewidth=2.5)
plt.plot(sample_touch2, label="Touch", color='lime', linewidth=2.5)
plt.plot(sample_hug2, label="Hug",  color='c', linewidth=2.5)
plt.plot(sample_choke2, label="Choke",  color='purple', linewidth=2.5)
plt.plot(sample_squeeze2, label="Squeeze",  color='violet', linewidth=2.5)
plt.plot(sample_shove2, label='Shove', color='orange', linewidth=2.5)
plt.plot(sample_hit2, label="Hit",  color='r', linewidth=2.5)
plt.grid(True)
plt.xlabel("readings",fontweight='bold',fontsize=16)
plt.ylabel("pressure (psi)",fontweight='bold',fontsize=16)
l1 = plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0, fontsize=16)
plt.tight_layout()

# %%
fig9 = plt.figure(1)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
#fig8.set_facecolor('lightgray')
ax = plt.axes()
ax.set_facecolor("whitesmoke")

fig9.suptitle('10 samples of touches MPX sensor 4', fontsize=16,  y=.995)
plt.plot(sample_quiet4, label="Quiet ", color='k', linewidth=2.5)
plt.plot(sample_caress4, label="Caress", color='b', linewidth=2.5)
plt.plot(sample_touch4, label="Touch", color='lime', linewidth=2.5)
plt.plot(sample_hug4, label="Hug",  color='c', linewidth=2.5)
plt.plot(sample_choke4, label="Choke",  color='purple', linewidth=2.5)
plt.plot(sample_squeeze4, label="Squeeze",  color='violet', linewidth=2.5)
plt.plot(sample_shove4, label='Shove', color='orange', linewidth=2.5)
plt.plot(sample_hit4, label="Hit",  color='r', linewidth=2.5)
plt.grid(True)
plt.xlabel("readings",fontweight='bold',fontsize=16)
plt.ylabel("pressure (psi)",fontweight='bold',fontsize=16)
l1 = plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0, fontsize=16)
plt.tight_layout()
plt.show()

# %%
dps_gyro_quiet_l = []
for i in gyro_quiet_l:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_quiet_l.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_quiet_l)
print(dps_gyro_quiet_l)

dps_gyro_quiet_r = []
for i in gyro_quiet_r:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_quiet_r.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_quiet_r)
print(dps_gyro_quiet_r)
# Out:
# [52, 53, 47, 47, 51, 50, 48, 53, 49, 49]
# ['0.40', '0.40', '0.36', '0.36', '0.39', '0.38', '0.37', '0.40', '0.37', '0.37']
# [-152, -151, -152, -154, -151, -153, -153, -153, -150, -152]
# ['-1.16', '-1.15', '-1.16', '-1.18', '-1.15', '-1.17', '-1.17', '-1.17', '-1.15', '-1.16']

# %%
dps_gyro_caress_l = []
for i in gyro_caress_l:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_caress_l.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_caress_l)
print(dps_gyro_caress_l)

dps_gyro_caress_r = []
for i in gyro_caress_r:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_caress_r.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_caress_r)
print(dps_gyro_caress_r)
# Out:
# [37, 41, -5, 42, 52, 43, 70, 47, 42, 55]
# ['0.28', '0.31', '-0.04', '0.32', '0.40', '0.33', '0.53', '0.36', '0.32', '0.42']
# [-158, -150, -190, -154, -134, -152, -121, -147, -144, -132]
# ['-1.21', '-1.15', '-1.45', '-1.18', '-1.02', '-1.16', '-0.92', '-1.12', '-1.10', '-1.01']

# %%
dps_gyro_touch_l = []
for i in gyro_touch_l:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_touch_l.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_touch_l)
print(dps_gyro_touch_l)

dps_gyro_touch_r = []
for i in gyro_touch_r:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_touch_r.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_touch_r)
print(dps_gyro_touch_r)
# Out:
# [49, 49, 48, 49, 43, 48, 49, 48, 47, 49]
# ['0.37', '0.37', '0.37', '0.37', '0.33', '0.37', '0.37', '0.37', '0.36', '0.37']
# [-151, -152, -146, -149, -155, -150, -150, -153, -149, -152]
# ['-1.15', '-1.16', '-1.11', '-1.14', '-1.18', '-1.15', '-1.15', '-1.17', '-1.14', '-1.16']

# %%
dps_gyro_hug_l = []
for i in gyro_hug_l:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_hug_l.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_hug_l)
print(dps_gyro_hug_l)

dps_gyro_hug_r = []
for i in gyro_hug_r:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_hug_r.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_hug_r)
print(dps_gyro_hug_r)
# Out:
# [43, 42, 40, 44, 45, 41, 40, 43, 38, 43]
# ['0.33', '0.32', '0.31', '0.34', '0.34', '0.31', '0.31', '0.33', '0.29', '0.33']
# [-149, -152, -155, -151, -154, -154, -152, -150, -150, -154]
# ['-1.14', '-1.16', '-1.18', '-1.15', '-1.18', '-1.18', '-1.16', '-1.15', '-1.15', '-1.18']

# %%
dps_gyro_choke_l = []
for i in gyro_choke_l:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_choke_l.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_choke_l)
print(dps_gyro_choke_l)

dps_gyro_choke_r = []
for i in gyro_choke_r:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_choke_r.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_choke_r)
print(dps_gyro_choke_r)
# Out:
# [50, 49, 40, 47, 42, 43, 47, 44, 45, 44]
# ['0.38', '0.37', '0.31', '0.36', '0.32', '0.33', '0.36', '0.34', '0.34', '0.34']
# [-153, -151, -154, -151, -154, -152, -152, -154, -152, -152]
# ['-1.17', '-1.15', '-1.18', '-1.15', '-1.18', '-1.16', '-1.16', '-1.18', '-1.16', '-1.16']

# %%
dps_gyro_shove_l = []
for i in gyro_shove_l:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_shove_l.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_shove_l)
print(dps_gyro_shove_l)

dps_gyro_shove_r = []
for i in gyro_shove_r:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_shove_r.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_shove_r)
print(dps_gyro_shove_r)
# Out:
# [65, -120, 94, 48, 51, 54, 54, 51, 48, 47]
# ['0.50', '-0.92', '0.72', '0.37', '0.39', '0.41', '0.41', '0.39', '0.37', '0.36']
# [-128, -454, -100, -157, -150, -150, -152, -152, -151, -152]
# ['-0.98', '-3.47', '-0.76', '-1.20', '-1.15', '-1.15', '-1.16', '-1.16', '-1.15', '-1.16']

# %%
dps_gyro_squeeze_l = []
for i in gyro_squeeze_l:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_squeeze_l.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_squeeze_l)
print(dps_gyro_squeeze_l)

dps_gyro_squeeze_r = []
for i in gyro_squeeze_r:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_squeeze_r.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_squeeze_r)
print(dps_gyro_squeeze_r)
# Out:
# [23, 39, 67, 87, -22, -136, 100, 83, 56, -70]
# ['0.18', '0.30', '0.51', '0.66', '-0.17', '-1.04', '0.76', '0.63', '0.43', '-0.53']
# [-197, -174, -77, -155, -239, -440, -109, -351, -133, -175]
# ['-1.50', '-1.33', '-0.59', '-1.18', '-1.82', '-3.36', '-0.83', '-2.68', '-1.02', '-1.34']

# %%
dps_gyro_hit_l = []
for i in gyro_hit_l:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_hit_l.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_hit_l)
print(dps_gyro_hit_l)

dps_gyro_hit_r = []
for i in gyro_hit_r:
    Gz = i / 131.0
    aa = "{:.2f}".format(Gz)
    dps_gyro_hit_r.append(aa)
    #print ("\tGz=%.2f" %Gz, u'\u00b0'+ "/s")
    #print(aa)
print(gyro_hit_r)
print(dps_gyro_hit_r)
# Out:
# [15, 59, -48, 55, 59, 56, 55, 52, 50, 55]
# ['0.11', '0.45', '-0.37', '0.42', '0.45', '0.43', '0.42', '0.40', '0.38', '0.42']
# [-188, -167, -234, -154, -155, -151, -152, -151, -151, -151]
# ['-1.44', '-1.27', '-1.79', '-1.18', '-1.18', '-1.15', '-1.16', '-1.15', '-1.15', '-1.15']

# %%
fig15 = plt.figure(1)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
ax = plt.axes()
ax.set_facecolor("whitesmoke")
fig15.suptitle('Left gyroscope values for 10 samples', fontsize=16)
plt.plot(dps_gyro_quiet_l, label="Quiet ", color='k', linewidth=2.5)
plt.plot(dps_gyro_caress_l, label="Caress", color='b', linewidth=2.5)
plt.plot(dps_gyro_touch_l, label="Touch", color='lime', linewidth=2.5)
plt.plot(dps_gyro_hug_l, label="Hug",  color='c', linewidth=2.5)
plt.plot(dps_gyro_choke_l, label="Choke",  color='purple', linewidth=2.5)
plt.plot(dps_gyro_squeeze_l, label="Squeeze",  color='violet', linewidth=2.5)
plt.plot(dps_gyro_shove_l, label='Shove', color='orange', linewidth=2.5)
plt.plot(dps_gyro_hit_l, label="Hit",  color='r', linewidth=2.5)
plt.grid(True)
plt.xlabel("readings",fontweight='bold',fontsize=16)
plt.ylabel("gyroscope (dps)",fontweight='bold',fontsize=16)
l1 = plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0, fontsize=16)
plt.tight_layout()
plt.savefig('./images_matplotlib/touches_dps_gyro_l.png')
plt.show()

# %%
fig16 = plt.figure(1)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
ax = plt.axes()
ax.set_facecolor("whitesmoke")
fig16.suptitle('Right gyroscope values for 10 samples', fontsize=16)
plt.plot(dps_gyro_quiet_r, label="Quiet ", color='k', linewidth=2.5)
plt.plot(dps_gyro_caress_r, label="Caress", color='b', linewidth=2.5)
plt.plot(dps_gyro_touch_r, label="Touch", color='lime', linewidth=2.5)
plt.plot(dps_gyro_hug_r, label="Hug",  color='c', linewidth=2.5)
plt.plot(dps_gyro_choke_r, label="Choke",  color='purple', linewidth=2.5)
plt.plot(dps_gyro_squeeze_r, label="Squeeze",  color='violet', linewidth=2.5)
plt.plot(dps_gyro_shove_r, label='Shove', color='orange', linewidth=2.5)
plt.plot(dps_gyro_hit_r, label="Hit",  color='r', linewidth=2.5)
plt.grid(True)
plt.xlabel("readings",fontweight='bold',fontsize=16)
plt.ylabel("gyroscope (dps)",fontweight='bold',fontsize=16)
l1 = plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0, fontsize=16)
plt.tight_layout();
